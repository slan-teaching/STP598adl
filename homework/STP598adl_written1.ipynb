# %% [markdown]
# # STP598 Advanced Deep Learning Models
# ## Written Assignment 1
# ### Due 11:59pm Friday Feb. 6, 2026 on Canvas
#
# ### name,  id

# %% [markdown]
# ## Question 1
#
# What is ResNet? (Exact copy of GPT answer may result in 0 point!)

# %% [markdown]
# ## Question 2
#
# What problem does ResNet solve? Why does ResNet work? (Exact copy of GPT answer may result in 0 point!)

# %% [markdown]
# ## Question 3
#
# Train a ResNet-50 on CIFAR-10. Split the dataset into training and testing sets. Make the following plots:
#
# * training loss and testing loss with respect to training epochs.
# * training error (for classification) and testing error with respect to training epochs.

# %% [markdown]
# ## Question 4
#
# Repeat the above question for ResNet-101.
